# %% [markdown]
# # Prepare Yourself

# %% [markdown]
# ### Single-Qubit Unitaries Table

# %% [markdown]
# 본 장은 지금까지의 내용을 복습하는 장으로, 지금까지 사용했던 모든 단일 큐비트 게이트를 행렬 표현, 회로도, 기저 상태에서의 동작으로 구분하여 나타낸다.

# %% [markdown]
# | 게이트 | 행렬 표현 | 회로 표현 방법 | 기저 상태 동작 |
# |---|---|---|---|
# | $X$ | $\begin{pmatrix} 0 & 1 \\ 1 & 0\end{pmatrix}$ | <img src="./assets/PY_fig1.png" width="150"/> | $X\ket{0} = 1 \\ X\ket{1} = 0$ |
# | $H$ | $\frac{1}{\sqrt{2}}\begin{pmatrix} 1 & 1 \\ 1 & -1\end{pmatrix}$ | <img src="./assets/PY_fig2.png" width="150"/> | $H\ket{0} = \frac{1}{\sqrt{2}}(\ket{0}+\ket{1}) \\ H\ket{1} = \frac{1}{\sqrt{2}}(\ket{0}-\ket{1})$ |
# | $Z$ | $\begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix}$  | <img src="./assets/PY_fig3.png" width="150"/> | $Z\ket{0} = \ket{0} \\ Z\ket{1} = -\ket{1}$ |
# | $S$ | $\begin{pmatrix} 1 & 0 \\ 0 & i \end{pmatrix}$  | <img src="./assets/PY_fig4.png" width="150"/> | $S\ket{0} = \ket{0} \\ S\ket{1} = i\ket{1}$ |
# | $T$ | $\begin{pmatrix} 1 & 0 \\ 0 & e^{i\pi/4} \end{pmatrix}$  | <img src="./assets/PY_fig5.png" width="150"/> | $T\ket{0} = \ket{0} \\ T\ket{1} = e^{i\pi/4}\ket{1}$ |
# | $Y$ | $\begin{pmatrix} 0 & -i \\ i & 0 \end{pmatrix}$  | <img src="./assets/PY_fig6.png" width="150"/> | $Y\ket{0} = i\ket{1} \\ Y\ket{1} = -i\ket{0}$ |
# | $RZ$ | $\begin{pmatrix} e^{-i\frac{\theta}{2}} & 0 \\ 0 & e^{i\frac{\theta}{2}} \end{pmatrix}$  | <img src="./assets/PY_fig7.png" width="150"/> | $RZ(\theta)\ket{0} = e^{-i\frac{\theta}{2}}\ket{0} \\ RZ(\theta)\ket{1} = e^{i\frac{\theta}{2}}\ket{1}$ |
# | $RX$ | $\begin{pmatrix} \cos(\frac{\theta}{2}) & -i\sin(\frac{\theta}{2}) \\ -i\sin(\frac{\theta}{2}) & \cos(\frac{\theta}{2}) \end{pmatrix}$  | <img src="./assets/PY_fig8.png" width="150"/> | $RX(\theta)\ket{0} = \cos\frac{\theta}{2}\ket{0} - i\sin\frac{\theta}{2}\ket{1} \\ RX(\theta)\ket{1} = -i\sin\frac{\theta}{2}\ket{0} + \cos\frac{\theta}{2}\ket{1}$ |
# | $RY$ | $\begin{pmatrix} \cos(\frac{\theta}{2}) & -\sin(\frac{\theta}{2}) \\ \sin(\frac{\theta}{2}) & \cos(\frac{\theta}{2}) \end{pmatrix}$ | <img src="./assets/PY_fig9.png" width="150"/> | $RY(\theta)\ket{0} = \cos\frac{\theta}{2}\ket{0} + \sin\frac{\theta}{2}\ket{1} \\ RY(\theta)\ket{1} = -\sin\frac{\theta}{2}\ket{0} + \cos\frac{\theta}{2}\ket{1}$ |

# %% [markdown]
# ---

# %% [markdown]
# ## Codercise

# %%
# !pip install numpy pennylane

# %%
import numpy as np
import pennylane as qp

# %% [markdown]
# ### I.8.1

# %% [markdown]
# <img src="./assets/PY_codercise1.png" width="300">

# %%
dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def prepare_state():
    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY OPERATIONS TO PREPARE THE TARGET STATE
    qp.Hadamard(wires=0)
    qp.RZ(5/4 * np.pi, wires=0)

    return qp.state()

# %% [markdown]
# ### I.8.2

# %% [markdown]
# <img src="./assets/PY_codercise2.png" width="300">

# %%
dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def prepare_state():
    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY OPERATIONS TO PREPARE THE TARGET STATE
    qp.RX(1/3 * np.pi, wires=0)

    return qp.state()

# %% [markdown]
# ### I.8.3

# %% [markdown]
# <img src="./assets/PY_codercise3.png" width="600">

# %%
v = np.array([0.52889389 - 0.14956775j, 0.67262317 + 0.49545818j])

##################
# YOUR CODE HERE #
##################

# CREATE A DEVICE

dev = qp.device("default.qubit", wires=1)

# CONSTRUCT A QNODE THAT USES qp.MottonenStatePreparation
# TO PREPARE A QUBIT IN STATE V, AND RETURN THE STATE

@qp.qnode(dev)
def prepare_state(state=v):
    qp.MottonenStatePreparation(state, wires=0)
    return qp.state()


# This will draw the quantum circuit and allow you to inspect the output gates
print(prepare_state(v))
print()
print(qp.draw(prepare_state, level="device")(v))
# Out:
# [0.52889389-0.14956775j 0.67262317+0.49545818j]
#
# 0: ──RY(1.98)──RZ(0.91)──GlobalPhase(-0.18)─┤  State
